# %%
from csv import reader

f=open("artworks (1).csv")
read=reader(f)
artwork= list(read)
artwork
# Out:
# [['Title',
#   'Artist',
#   'Nationality',
#   'BeginDate',
#   'EndDate',
#   'Gender',
#   'Date',
#   'Department'],
#  ['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   '(American)',
#   '(1947)',
#   '(2013)',
#   '(Female)',
#   '1986',
#   'Prints & Illustrated Books'],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   '(Spanish)',
#   '(1916)',
#   '(2007)',
#   '(Male)',
#   '1978',
#   'Prints & Illustrated Books'],
#  ['Tailpiece (page 55) from SAGESSE',
#   'Maurice Denis',
#   '(French)',
#   '(1870)',
#   '(1943)',
#   '(Male)',
#   '1889-1911',
#   'Prints & Illustrated Books'],
#  ['Headpiece (page 129) from LIVRET DE FOLASTRIES, \xc3\x80 JANOT PARISIEN',
#   'Aristide Maillol',
#   '(French)',
#   '(1861)',
#   '(1944)',
#   '(Male)',
#   '1927-1940',
#   'Prints & Illustrated Books'],
#  ['97 rue du Bac',
#   'Eug\xc3\xa8ne Atget',
#   '(French)',
#   '(1857)',
#   '(1927)',
# ...

# %%
for item in artwork[1:]:
    nationality = item[2]
    gender = item[5]
    #print gender
    nationality = nationality.replace("(","")           #replace string pr km hota ha
    nationality = nationality.replace(")","")                #yei km gender k lie b krna ha
    print nationality 
    item[2]=nationality
    gender = gender.replace("(","")           #replace string pr km hota ha
    gender = gender.replace(")","")                #yei km gender k lie b krna ha
    print gender
    item[5]=gender
# Out:
# American
# Female
# Spanish
# Male
# French
# Male
# French
# Male
# French
# Male
# American
# Male
# French
# Male
# American
# Male
# South African
# Female
# Canadian
# Male
# French
# Male
# American
# Male
# Czech
# Male
# American
# Male
# American
# Male
# American
# Male
# Belgian
# Male
# American
# Male
# American
# Male
# Spanish
# Male
# American
# Male
# Russian
# Female
# American
# Male
# French
# Male
# French
# Male
# French
# Male
# British
# Female
# French
# Male
# French
# Male
# German
# Male
# Belgian
# Male
#
#
# American
# Male
# American
# Male
# American
# Male
# Swiss
# Male
#
# Male
# American
# Male
# American
# Male
# Polish
# Male
# British
# Male
# American
# Male
# American
# Male
# Belgian
# Male
# American
# Male
# Japanese
# Male
# American
# Male
# American
# Male
# Spanish
# Male
# American
# Male
# French
# Male
# American
# Male
# American
# Male
# American
# Male
# American
# Male
# French
# Male
# American
# Female
# American
# Male
# ...

# %%
for item in artwork[1:]:                           #yei km gender k lie 
    nationality = item[2]
    gender = item[5]
    if nationality =="":
        nationality = "unknown"
    print(nationality)
    if gender =="()":
        gender = "unknown"
    item[2]= nationality
    item[5]= gender
# Out:
# American
# Spanish
# French
# French
# French
# American
# French
# American
# South African
# Canadian
# French
# American
# Czech
# American
# American
# American
# Belgian
# American
# American
# Spanish
# American
# Russian
# American
# French
# French
# French
# British
# French
# French
# German
# Belgian
# unknown
# American
# American
# American
# Swiss
# unknown
# American
# American
# Polish
# British
# American
# American
# Belgian
# American
# Japanese
# American
# American
# Spanish
# American
# French
# American
# American
# American
# American
# French
# American
# American
# French
# American
# American
# Portuguese
# American
# American
# Austrian
# Swiss
# German
# American
# American
# French
# British
# American
# French
# American
# British
# German
# French
# French
# Australian
# American
# French
# Spanish
# German
# American
# American
# French
# American
# American
# American
# French
# Italian
# American
# American
# American
# American
# American
# French
# ...

# %%
for row in artwork[1:20]:
    print row
# Out:
# ['Dress MacLeod from Tartan Sets', 'Sarah Charlesworth', 'American', '(1947)', '(2013)', 'Female', '1986', 'Prints & Illustrated Books']
# ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA', 'Pablo Palazuelo', 'Spanish', '(1916)', '(2007)', 'Male', '1978', 'Prints & Illustrated Books']
# ['Tailpiece (page 55) from SAGESSE', 'Maurice Denis', 'French', '(1870)', '(1943)', 'Male', '1889-1911', 'Prints & Illustrated Books']
# ['Headpiece (page 129) from LIVRET DE FOLASTRIES, \xc3\x80 JANOT PARISIEN', 'Aristide Maillol', 'French', '(1861)', '(1944)', 'Male', '1927-1940', 'Prints & Illustrated Books']
# ['97 rue du Bac', 'Eug\xc3\xa8ne Atget', 'French', '(1857)', '(1927)', 'Male', '1903', 'Photography']
# ['Pictorial ornament (folio 11) from WOODCUTS', 'Antonio Frasconi', 'American', '(1919)', '(2013)', 'Male', '1957', 'Prints & Illustrated Books']
# ...

# %%
#ek function banana ha jisme years me jo minus or brackets are hain wo remove hojaein or int me ana chie year 
for i in artwork[1:]:
    date = i[6]
    if "-" or "(" or ")" in date:
        date = date.replace("-","")
        date = date.replace("(","")
        date = date.replace(")","")
        print date
# Out:
# 1986
# 1978
# 18891911
# 19271940
# 1903
# 1957
# 1924
# 19781983
# 2001
# 1941
# 19491950
# 1963
# 19081911
# 1934
# 1997
# 19311933
# 1972
# 1967
# 19231924
# 1979
# 19251927
# 1929
# 1972
# 1974
# 1957
# 19201930
# 1974
# 1915
# 1912
# 19881990
# 1925
# c. 1925
# 1980
# 1964
# 1968
# 1969
# 1934
# 1953
# 1971
# 1988
# 1818
# 2002
# 1926
# 1969
# 1914
# 1979
# 1968
# 1979
# 1966
# 1904
# 1949
# 1981
# 1970
# 1969
# 1972
# 19231925
# 1967
# 1932
# 1928
# 1965
# 2003
# 19711974
# 1983
# 1930
# 1946
# 1984
# 2006
# c. 1885
# 1942
# 1913
# 2015
# 1987
# 19471949
# 1965
# 1818
# 1961
# 1925
# 19161932
# 1962
# 1944
# 1930
# 1991
# 19911994
# 2008
# 1975
# 1893
# 1966
# 19681969
# 19641968
# 19281939
# 1969
# 1942
# 1980
# 1955
# 1930
# c. 19551960
# 1922
# c.1934
# 1903
# 2008
# 1962
# 1944
# 19141918
# 2003
# 2012
# 1965
# 1865
# 1976
# 1902
# 2003
# 2010
# 1944
# 1963
# 1875
# 1948
# 1990
# 1913
# 1958
# 1921
# 1970
# 1950
# 2004
# 1926
# 1973
# 1915
# 2003
# 1973
# 1986
# 1982
# ...

# %%
def clean_date(date,index):
    for i in artwork[1:]:
        date = i[index]
        if "-" or "(" or ")" in date:
            date = date.replace("-","")
            date = date.replace("(","")
            date = date.replace(")","")
            return clean_data

# %%
clean_data(,2)
# Out:
#   File "<ipython-input-7-5bebde409d49>", line 1
#     clean_data(,2)
#                ^
# SyntaxError: invalid syntax

# %%
for i in artwork[1:]:
    dob = i[3]
    if "-" or "(" or ")" in dob:
        dob = dob.replace("-","")
        dob = dob.replace("(","")
        dob = dob.replace(")","")
        print dob
for i in artwork[1:]:
    doe = i[4]
    if "-" or "(" or ")" in doe:
        doe = doe.replace("-","")
        doe = doe.replace("(","")
        doe = doe.replace(")","")
        print doe

# %%
for i in artwork[1:10]:
    print(int(i[4]-int(i[3])))

# %%
for item in artwork[1:]:
    date = item[-2]
    print(date)

# %%
bad_char = ["(",")","c","C","s","'s","c.","."," ","-","_"]
def clean_char(date):
            for i in bad_char:
                date = date.replace(i,"")
            return date

# %%
clean_char("1945s")

# %%
for i in artwork:
    print(i[-2])

# %%
for i in artwork[1:]:
    date = i[-2]
    date = clean_char(date)
    i[-2]= date
    print(i[-2])

# %%
for i in artwork[1:7]:
    print(i)

# %%
for i in artwork[1:]:
    date = i[-2]
    if "-"in date:
        date=date.split
        print date
    op = int(date[:4])         #split method list me dal dega or jo split kroge usse hata dega
    en = int(date[5:])
    date = date.split("-")
    print(date)

# %%
for i in artwork[1:]:
    date = i[-2]
    if "-"in date:
       # print date
    op = int(date[0:4])            
    en = int(date[5:])
    avg_date = round(op+en)/2
    i[-2]=avg_date

# %%
for i in artwork[1:]:
    print(i)

# %%
1+3

# %%
import csv
f = open("art_clean.csv","w")           # w k sat file open hojaigi agr na b hoi tau ek new nam se
writer = csv.writer(f,delimiter=",")           #delimiter separated k lie  use hota ha yani file ko kis chez se separate kna ha
writer.writerow(artwork[0])
for data in artwork[1:]:
    writer.writerow(data)
f.close()                     #last line file ko cliose k l lie

# %%
artwork[0]
