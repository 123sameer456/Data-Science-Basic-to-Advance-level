# %%
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv("dataset.csv")
print(dataset.info())
print(dataset.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 9 columns):
# lat          189 non-null float64
# lng          189 non-null float64
# desc         189 non-null object
# zip          189 non-null int64
# title        189 non-null object
# timeStamp    189 non-null object
# twp          189 non-null object
# addr         189 non-null object
# e            189 non-null int64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 13.4+ KB
# None
#          lat        lng                                               desc  \
# 0  30.333596 -95.595595  8931;  MONTGOMERY; Station 311; 2016-06-02 @ 1...
# 1  32.387090 -86.276106          600  ; MONTGOMERY; 2016-02-12 @ 18:44:37;
# 2  40.334197 -75.922495  WALNUT ST & CHERRY ST;  BERKS COUNTY; Station ...
# 3  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 4  40.312181 -75.574260  CHARLOTTE ST & MILES RD;  NEW HANOVER; Station...
#
# ...

# %%
#compute --- create a countplot month wise
#question: which saw a highest calls for fire?
#answer:

# %%
dataset.describe()
# Out:
#               lat         lng           zip      e
# count  189.000000  189.000000    189.000000  189.0
# mean    40.013518  -75.369114  19558.899471    1.0
# std      0.906790    1.688307   4401.053889    0.0
# min     30.333596  -95.595595  18964.000000    1.0
# 25%     40.072731  -75.178199  19150.000000    1.0
# 50%     40.074108  -75.158311  19150.000000    1.0
# 75%     40.082890  -75.155969  19150.000000    1.0
# max     40.334197  -75.155969  77316.000000    1.0

# %%
dataset
# Out:
#            lat        lng                                               desc  \
# 0    30.333596 -95.595595  8931;  MONTGOMERY; Station 311; 2016-06-02 @ 1...
# 1    32.387090 -86.276106          600  ; MONTGOMERY; 2016-02-12 @ 18:44:37;
# 2    40.334197 -75.922495  WALNUT ST & CHERRY ST;  BERKS COUNTY; Station ...
# 3    40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 4    40.312181 -75.574260  CHARLOTTE ST & MILES RD;  NEW HANOVER; Station...
# 5    40.320966 -75.611349  WILSON AVE & E PHILADELPHIA AVE;  DOUGLASS; St...
# 6    40.290693 -75.576661  SWAMP PIKE & ROMIG RD;  NEW HANOVER; Station 3...
# 7    40.276304 -75.565024  SWAMP PIKE & SANATOGA RD; NEW HANOVER; 2015-12...
# 8    40.284455 -75.574528  CEDAR LN & WILLOW LN;  NEW HANOVER; Station 33...
# 9    40.276304 -75.565024  SWAMP PIKE & SANATOGA RD; NEW HANOVER; 2015-12...
# 10   40.313464 -75.606652  MOORE DR & S WERSTLER AVE;  DOUGLASS; Station ...
# ...

# %%
dataset["timeStamp"] = pd.to_datetime(dataset.timeStamp)

# %%
dataset.dtypes
# Out:
# lat                 float64
# lng                 float64
# desc                 object
# zip                   int64
# title                object
# timeStamp    datetime64[ns]
# twp                  object
# addr                 object
# e                     int64
# dtype: object

# %%
dataset.timeStamp.dt.month
# Out:
# 0       6
# 1       2
# 2       9
# 3      12
# 4      12
# 5      12
# 6      12
# 7      12
# 8      12
# 9      12
# 10     12
# 11     12
# 12     12
# 13     12
# 14      7
# 15      7
# 16      7
# 17      7
# 18      7
# 19      7
# 20      7
# 21      7
# 22      7
# 23      7
# 24      7
# 25      7
# 26      7
# 27      8
# 28      8
# 29      8
#        ..
# 159    11
# 160    11
# 161    11
# 162    11
# 163    11
# 164    11
# 165    11
# 166    11
# 167    11
# 168    11
# 169    11
# 170    11
# 171    11
# 172    11
# 173    11
# 174    12
# 175    12
# 176    11
# 177    11
# 178    11
# 179    11
# 180    11
# 181    11
# 182    11
# 183    11
# 184    11
# 185    11
# 186    11
# 187    11
# 188    11
# Name: timeStamp, Length: 189, dtype: int64

# %%
dataset["month"] = dataset.timeStamp.dt.month

# %%
dataset
# Out:
#            lat        lng                                               desc  \
# 0    30.333596 -95.595595  8931;  MONTGOMERY; Station 311; 2016-06-02 @ 1...
# 1    32.387090 -86.276106          600  ; MONTGOMERY; 2016-02-12 @ 18:44:37;
# 2    40.334197 -75.922495  WALNUT ST & CHERRY ST;  BERKS COUNTY; Station ...
# 3    40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 4    40.312181 -75.574260  CHARLOTTE ST & MILES RD;  NEW HANOVER; Station...
# 5    40.320966 -75.611349  WILSON AVE & E PHILADELPHIA AVE;  DOUGLASS; St...
# 6    40.290693 -75.576661  SWAMP PIKE & ROMIG RD;  NEW HANOVER; Station 3...
# 7    40.276304 -75.565024  SWAMP PIKE & SANATOGA RD; NEW HANOVER; 2015-12...
# 8    40.284455 -75.574528  CEDAR LN & WILLOW LN;  NEW HANOVER; Station 33...
# 9    40.276304 -75.565024  SWAMP PIKE & SANATOGA RD; NEW HANOVER; 2015-12...
# 10   40.313464 -75.606652  MOORE DR & S WERSTLER AVE;  DOUGLASS; Station ...
# ...

# %%
a=dataset.month.value_counts().sort_index()
a
# Out:
# 2      1
# 6      1
# 7     13
# 8     55
# 9     24
# 10    28
# 11    54
# 12    13
# Name: month, dtype: int64

# %%
a.plot(x="Month",y="frequency",kind= "bar", title= "countplot month wise " ,figsize= (5,7),color= "green")

# %%
a = []
for i in dataset.month:
    if i == 6:
        a.append("true")
    else:
        a.append("false")

# %%
a
# Out:
# ['true',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
#  'false',
# ...

# %%
june = pd.Series(a)

# %%
june
# Out:
# 0       true
# 1      false
# 2      false
# 3      false
# 4      false
# 5      false
# 6      false
# 7      false
# 8      false
# 9      false
# 10     false
# 11     false
# 12     false
# 13     false
# 14     false
# 15     false
# 16     false
# 17     false
# 18     false
# 19     false
# 20     false
# 21     false
# 22     false
# 23     false
# 24     false
# 25     false
# 26     false
# 27     false
# 28     false
# 29     false
#        ...
# 159    false
# 160    false
# 161    false
# 162    false
# 163    false
# 164    false
# 165    false
# 166    false
# 167    false
# 168    false
# 169    false
# 170    false
# 171    false
# 172    false
# 173    false
# 174    false
# 175    false
# 176    false
# 177    false
# 178    false
# 179    false
# 180    false
# 181    false
# 182    false
# 183    false
# 184    false
# 185    false
# 186    false
# 187    false
# 188    false
# Length: 189, dtype: object

# %%
dataset["june"] = june

# %%
dataset
# Out:
#            lat        lng                                               desc  \
# 0    30.333596 -95.595595  8931;  MONTGOMERY; Station 311; 2016-06-02 @ 1...
# 1    32.387090 -86.276106          600  ; MONTGOMERY; 2016-02-12 @ 18:44:37;
# 2    40.334197 -75.922495  WALNUT ST & CHERRY ST;  BERKS COUNTY; Station ...
# 3    40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 4    40.312181 -75.574260  CHARLOTTE ST & MILES RD;  NEW HANOVER; Station...
# 5    40.320966 -75.611349  WILSON AVE & E PHILADELPHIA AVE;  DOUGLASS; St...
# 6    40.290693 -75.576661  SWAMP PIKE & ROMIG RD;  NEW HANOVER; Station 3...
# 7    40.276304 -75.565024  SWAMP PIKE & SANATOGA RD; NEW HANOVER; 2015-12...
# 8    40.284455 -75.574528  CEDAR LN & WILLOW LN;  NEW HANOVER; Station 33...
# 9    40.276304 -75.565024  SWAMP PIKE & SANATOGA RD; NEW HANOVER; 2015-12...
# 10   40.313464 -75.606652  MOORE DR & S WERSTLER AVE;  DOUGLASS; Station ...
# ...

# %%
dataset[june]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-5a834867a5a2> in <module>()
# ----> 1 dataset[june]
#
# D:\ProgramData\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# D:\ProgramData\Anaconda2\lib\site-packages\pandas\core\indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ...
