# %%
from csv import reader

f=open("artworks_clean.csv")
read=reader(f)
artwork= list(read)
header = artwork[1]
artworks = artwork[1:]

# %%
header
# Out:
# ['Dress MacLeod from Tartan Sets',
#  'Sarah Charlesworth',
#  'American',
#  '1947',
#  '2013',
#  'Female',
#  '1986',
#  'Prints & Illustrated Books']

# %%
artworks
# Out:
# [['Dress MacLeod from Tartan Sets',
#   'Sarah Charlesworth',
#   'American',
#   '1947',
#   '2013',
#   'Female',
#   '1986',
#   'Prints & Illustrated Books'],
#  ['Duplicate of plate from folio 11 verso (supplementary suite, plate 4) from ARDICIA',
#   'Pablo Palazuelo',
#   'Spanish',
#   '1916',
#   '2007',
#   'Male',
#   '1978',
#   'Prints & Illustrated Books'],
#  ['Tailpiece (page 55) from SAGESSE',
#   'Maurice Denis',
#   'French',
#   '1870',
#   '1943',
#   'Male',
#   '1900',
#   'Prints & Illustrated Books'],
#  ['Headpiece (page 129) from LIVRET DE FOLASTRIES, \xc3\x80 JANOT PARISIEN',
#   'Aristide Maillol',
#   'French',
#   '1861',
#   '1944',
#   'Male',
#   '1934',
#   'Prints & Illustrated Books'],
#  ['97 rue du Bac',
#   'Eug\xc3\xa8ne Atget',
#   'French',
#   '1857',
#   '1927',
#   'Male',
#   '1903',
#   'Photography'],
#  ['Pictorial ornament (folio 11) from WOODCUTS',
#   'Antonio Frasconi',
#   'American',
#   '1919',
#   '2013',
#   'Male',
# ...

# %%
for row in artworks:
    dob = row[3]
    if type(dob)==int:
        
        dob

# %%
for row in artworks:
    dob = row[3]
    if dob != "":
        dob = int(dob)
        print (dob)
    if dob == "":
        print("unkonwn")
# Out:
# 1947
# 1916
# 1870
# 1861
# 1857
# 1919
# 1857
# 1928
# 1964
# 1882
# 1901
# 1935
# 1871
# 1894
# 1955
# 1878
# 1927
# 1936
# 1867
# 1932
# 1886
# 1894
# 1938
# 1926
# 1898
# 1867
# 1947
# 1868
# 1857
# 1938
# 1889
# unkonwn
# 1928
# 1934
# 1929
# 1930
# unkonwn
# 1919
# 1901
# 1949
# 1753
# 1973
# 1902
# 1927
# 1867
# 1933
# 1928
# 1934
# 1893
# 1867
# 1887
# 1925
# 1938
# 1929
# 1936
# 1857
# 1948
# 1886
# 1868
# 1931
# 1911
# 1933
# 1943
# 1886
# 1870
# 1943
# 1954
# 1843
# 1898
# 1857
# 1966
# 1957
# 1903
# 1903
# 1753
# 1909
# 1857
# 1871
# 1927
# 1890
# 1883
# 1927
# 1945
# 1954
# 1947
# 1864
# 1904
# 1948
# 1931
# 1871
# 1955
# 1890
# 1934
# 1915
# 1886
# 1931
# 1857
# 1886
# 1857
# 1958
# 1934
# 1867
# 1877
# 1978
# 1963
# 1922
# 1831
# 1947
# 1857
# unkonwn
# 1967
# 1893
# 1905
# 1830
# 1924
# 1934
# 1881
# 1910
# 1886
# 1936
# 1901
# 1911
# 1890
# 1943
# 1871
# 1911
# 1946
# 1954
# 1938
# 1871
# 1885
# 1917
# 1868
# 1923
# 1909
# 1870
# 1900
# 2005
# 1884
# 1947
# 1913
# ...

# %%
for row in artworks:
    doe = row[4]
    if doe != "":
        doe = int(doe)
        print(doe)
    if doe == "":
        print("unknown")
# Out:
# 2013
# 2007
# 1943
# 1944
# 1927
# 2013
# 1927
# 1984
# unknown
# 1953
# 1985
# unknown
# 1957
# 1972
# unknown
# 1965
# unknown
# unknown
# 1959
# unknown
# 1969
# 1958
# unknown
# 1987
# 1976
# 1947
# unknown
# 1941
# 1927
# unknown
# 1972
# unknown
# 2007
# 2006
# unknown
# 1998
# unknown
# 2013
# 1978
# unknown
# 1828
# unknown
# 1988
# unknown
# 1959
# unknown
# 1987
# unknown
# 1983
# 1959
# 1985
# 2008
# 2011
# unknown
# unknown
# 1927
# unknown
# 1969
# 1941
# 1978
# 2010
# unknown
# unknown
# 1969
# 1956
# unknown
# unknown
# 1908
# 1957
# 1927
# unknown
# 1996
# 1976
# 1991
# 1828
# 1981
# 1927
# 1958
# 1982
# 1976
# 1956
# unknown
# 2014
# unknown
# unknown
# 1901
# 1997
# unknown
# 2006
# 1958
# unknown
# 1965
# unknown
# 2004
# 1969
# 1978
# 1927
# 1969
# 1927
# unknown
# 2016
# 1959
# 1960
# unknown
# unknown
# 2000
# 1913
# unknown
# 1927
# unknown
# unknown
# 1983
# 1970
# 1904
# unknown
# unknown
# 1955
# 2007
# 1969
# unknown
# 1985
# 2010
# 1976
# unknown
# 1951
# ...

# %%
for i in artworks[1:10]:
    j = i[3]
    k = i[4]
    if type(i[3]) and type(i[4])== int:
        
        a = i[4]-i[3]
        print(a)

# %%
for row in artworks:
    date = row[6]
    if date != "":
        date = int(date)
        print(date)
# Out:
# 1986
# 1978
# 1900
# 1934
# 1903
# 1957
# 1924
# 1980
# 2001
# 1941
# 1950
# 1963
# 1910
# 1934
# 1997
# 1932
# 1972
# 1967
# 1924
# 1979
# 1926
# 1929
# 1972
# 1974
# 1957
# 1925
# 1974
# 1915
# 1912
# 1989
# 1925
# 1925
# 1980
# 1964
# 1968
# 1969
# 1934
# 1953
# 1971
# 1988
# 1818
# 2002
# 1926
# 1969
# 1914
# 1979
# 1968
# 1979
# 1966
# 1904
# 1949
# 1981
# 1970
# 1969
# 1972
# 1924
# 1967
# 1932
# 1928
# 1965
# 2003
# 1972
# 1983
# 1930
# 1946
# 1984
# 2006
# 1885
# 1942
# 1913
# 2015
# 1987
# 1948
# 1965
# 1818
# 1961
# 1925
# 1924
# 1962
# 1944
# 1930
# 1991
# 1992
# 2008
# 1975
# 1893
# 1966
# 1968
# 1966
# 1934
# 1969
# 1942
# 1980
# 1955
# 1930
# 1958
# 1922
# 1934
# 1903
# 2008
# 1962
# 1944
# 1916
# 2003
# 2012
# 1965
# 1865
# 1976
# 1902
# 2003
# 2010
# 1944
# 1963
# 1875
# 1948
# 1990
# 1913
# 1958
# 1921
# 1970
# 1950
# 2004
# 1926
# 1973
# 1915
# 2003
# 1973
# 1986
# 1982
# 1910
# 1934
# 1971
# 1926
# 1960
# 1939
# 1893
# 1952
# 2007
# 1940
# 1995
# 1973
# 1939
# ...

# %%
for i in artworks:
    dob = i[3]  
    print(dob)
# Out:
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# <type 'int'>
# ...

# %%
ages = []
for i in artworks[1:]:
    dob = (i[3])
    date = int(i[6])
     if type(dob)==int:
        age = date - dob
    else:
        age = 0
        ages.append(age)
ages
# Out:
#   File "<ipython-input-71-8e79e807b221>", line 5
#     if type(dob)==int:
#     ^
# IndentationError: unexpected indent

# %%
ek final list banani ha jisme agr kisi ki age 20 se zaida ha tau thk ha lkn agr 20 se km age ho tau age ki jaga pr unknwn likhan ha

# %%
final_lst = []
for i in ages[:]:
    if i <= 20:
        i.append(final_lst)
        final_lst
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-4957a9b55945> in <module>()
#       2 for i in ages[:]:
#       3     if i <= 20:
# ----> 4         i.append(final_lst)
#       5         final_lst
#       6
#
# AttributeError: 'int' object has no attribute 'append'

# %%
final_age = [45,"unknown",27 ,52,"unknown",34,54,34] # is trha ka data aega

# %%
decade = ["20s","40s"] ek aisi list bnani ha jsme same sound ek jahga ae yani 40s ya 50s

# %%
decade_dic ={"20s":0,"30s":0,"40s":0,"50s":0,"60s":0,"70s":0,"80s:0"}
for i in final_age:
    if i <=20:
        decade["20s"]=unknown
    elif  20 <i <=30:
        decade_dic["30s"]+=1
    elif  30 <i <=40:
        decade_dic["40s"]+=1
    elif  40 <i <=50:
        decade_dic["40s"]+=1
    elif  50 <i <=60:
        decade_dic["50s"]+=1
    elif  60 <i <=70:
        decade_dic["60s"]+=1
    elif  70 <i <=80:
        decade_dic["70s"]+=1
    else:
          decade_dic["80s"]+=1
            decade_dic
# Out:
#   File "<ipython-input-47-96866e91edc8>", line 1
#     decade_dic ={"20s":0,"30s":0,"40s":0,"50s":0,"60s":0,"70s":0,"80s:0"}
#                                                                         ^
# SyntaxError: invalid syntax

# %%
deca_freq = {}     #finaL AGE KI FREQUENCY B BANANI HA
for i in decades:
    if i in deca_freq:
        deca_freq[i]+=1
    else:
        dca_freq[i]=1
deca_freq

# %%
name = "waqas"
fname = "munawar"
print("my name is " + name+". my father name is "+fname)
# Out:
# my name is waqas. my father name is munawar

# %%
#print("my name is {}. my father name is {}".format(name,fname) #string format
tem = "my name is {n}. my father name is {f}"
print(tem.format(f=fname,n=name))
# Out:
# my name is waqas. my father name is munawar

# %%
artist_freq = {}
for i in artworks:
    artist = i[1]
    if artist in artist_freq:
        artist_freq[artist]+=1
    else:
        artist_freq[artist] = 1
artist_freq
# Out:
# {"Aleksei Den'shin": 1,
#  'Robert Massin': 1,
#  'Jozsef Rippl-R\xc3\xb3nai': 1,
#  'Linda Connor': 2,
#  'Lisandro Alonso': 1,
#  'Denis Constanduros': 1,
#  'Viacheslav Pakulin': 1,
#  'Dave Heath': 2,
#  'Clorindo Testa': 1,
#  'Francis Bedford': 3,
#  'Peggy Bacon': 9,
#  'Christian Rohlfs': 8,
#  'Mary Kocol': 1,
#  'Monika Baer': 1,
#  'Maria Lassnig': 1,
#  'Charles Reutlinger': 1,
#  'Walter Stein': 4,
#  'Dorine van der Klei': 4,
#  'George Platt Lynes': 2,
#  'Diane Lewis': 1,
#  'Andr\xc3\xa1s Wahorn': 2,
#  'Charles H. Currier': 1,
#  'Richard S\xc3\xbcssmuth': 2,
#  'Georges Blanc': 1,
#  'John Craxton': 2,
#  'Max Bill': 5,
#  'Giancarlo Piretti': 1,
#  'Niko Kralj': 1,
#  'Chryssa': 8,
#  'Bishin Jumonji': 1,
#  'W. & D. Downey': 1,
#  'Harry Suchland': 1,
#  'Ilya Bolotowsky': 1,
#  'Stephen Antonakos': 11,
#  'Philip-Lorca diCorcia': 9,
#  'Michel Parmentier': 1,
#  'Richard Bosman': 7,
#  'Agnes Lyall': 1,
#  'Andr\xc3\xa9 Collot': 5,
#  'Fabian Marcaccio': 1,
# ...

# %%
artist_freq.items()
# Out:
# [("Aleksei Den'shin", 1),
#  ('Robert Massin', 1),
#  ('Jozsef Rippl-R\xc3\xb3nai', 1),
#  ('Linda Connor', 2),
#  ('Lisandro Alonso', 1),
#  ('Denis Constanduros', 1),
#  ('Viacheslav Pakulin', 1),
#  ('Dave Heath', 2),
#  ('Clorindo Testa', 1),
#  ('Francis Bedford', 3),
#  ('Peggy Bacon', 9),
#  ('Christian Rohlfs', 8),
#  ('Mary Kocol', 1),
#  ('Monika Baer', 1),
#  ('Maria Lassnig', 1),
#  ('Charles Reutlinger', 1),
#  ('Walter Stein', 4),
#  ('Dorine van der Klei', 4),
#  ('George Platt Lynes', 2),
#  ('Diane Lewis', 1),
#  ('Andr\xc3\xa1s Wahorn', 2),
#  ('Charles H. Currier', 1),
#  ('Richard S\xc3\xbcssmuth', 2),
#  ('Georges Blanc', 1),
#  ('John Craxton', 2),
#  ('Max Bill', 5),
#  ('Giancarlo Piretti', 1),
#  ('Niko Kralj', 1),
#  ('Chryssa', 8),
#  ('Bishin Jumonji', 1),
#  ('W. & D. Downey', 1),
#  ('Harry Suchland', 1),
#  ('Ilya Bolotowsky', 1),
#  ('Stephen Antonakos', 11),
#  ('Philip-Lorca diCorcia', 9),
#  ('Michel Parmentier', 1),
#  ('Richard Bosman', 7),
# ...

# %%
for key,value in artist_freq.items():
    print(artist_freq[key],key)
# Out:
# (1, "Aleksei Den'shin")
# (1, 'Robert Massin')
# (1, 'Jozsef Rippl-R\xc3\xb3nai')
# (2, 'Linda Connor')
# (1, 'Lisandro Alonso')
# (1, 'Denis Constanduros')
# (1, 'Viacheslav Pakulin')
# (2, 'Dave Heath')
# (1, 'Clorindo Testa')
# (3, 'Francis Bedford')
# (9, 'Peggy Bacon')
# (8, 'Christian Rohlfs')
# (1, 'Mary Kocol')
# (1, 'Monika Baer')
# (1, 'Maria Lassnig')
# (1, 'Charles Reutlinger')
# (4, 'Walter Stein')
# (4, 'Dorine van der Klei')
# (2, 'George Platt Lynes')
# (1, 'Diane Lewis')
# (2, 'Andr\xc3\xa1s Wahorn')
# (1, 'Charles H. Currier')
# (2, 'Richard S\xc3\xbcssmuth')
# (1, 'Georges Blanc')
# (2, 'John Craxton')
# (5, 'Max Bill')
# (1, 'Giancarlo Piretti')
# (1, 'Niko Kralj')
# (8, 'Chryssa')
# (1, 'Bishin Jumonji')
# (1, 'W. & D. Downey')
# (1, 'Harry Suchland')
# (1, 'Ilya Bolotowsky')
# (11, 'Stephen Antonakos')
# (9, 'Philip-Lorca diCorcia')
# (1, 'Michel Parmentier')
# (7, 'Richard Bosman')
# (1, 'Agnes Lyall')
# (5, 'Andr\xc3\xa9 Collot')
# (1, 'Fabian Marcaccio')
# ...

# %%
for key,value in artist_freq.items():
    temp = f"there are {value} artworks(s) by {key}"
    print(temp)

# %%
pop = {"china": 1223,"india":34234235,"pak":3243243}

# %%
for key in pop:
    name = key
    population = pop[key]
    print("population of {0} is {1:,.2f}.".format(name,population))

# %%
deca_freq = {}
for i in decades:
    if i in deca_freq:
        deca
