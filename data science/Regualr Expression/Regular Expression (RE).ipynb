# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hacker = pd.read_csv("hacker_news.csv")

# %%
hacker
# Out:
#              id                                              title  \
# 0      12224879                          Interactive Dynamic Video
# 1      10975351  How to Use Open Source and Shut the Fuck Up at...
# 2      11964716  Florida DJs May Face Felony for April Fools' W...
# 3      11919867       Technology ventures: From Idea to Enterprise
# 4      10301696  Note by Note: The Making of Steinway L1037 (2007)
# 5      10482257  Title II kills investment? Comcast and other I...
# 6      10557283                     Nuts and Bolts Business Advice
# 7      12296411        Ask HN: How to improve my personal website?
# 8      11337617  Shims, Jigs and Other Woodworking Concepts to ...
# 9      10379326                             That self-appendectomy
# 10     11370829  Crate raises $4M seed round for its next-gen S...
# 11     11665197  Advertising Cannot Maintain the Internet. Here...
# 12     11981466                                     Coding Is Over
# ...

# %%
titles = hacker["title"]

# %%
titles.head()
# Out:
# 0                            Interactive Dynamic Video
# 1    How to Use Open Source and Shut the Fuck Up at...
# 2    Florida DJs May Face Felony for April Fools' W...
# 3         Technology ventures: From Idea to Enterprise
# 4    Note by Note: The Making of Steinway L1037 (2007)
# Name: title, dtype: object

# %%
pattern = "([Pp]ython)" #here () showing a capturing group

# %%
titles.str.extract(pattern)[0].value_counts(dropna = False)
# Out:
# NaN       19940
# Python      149
# python       11
# Name: 0, dtype: int64

# %%
"send", "mend","mend"
"[sbm]end"
# Out:
# '[sbm]end'

# %%
import re
count = 0
for title in titles:
    if re.search(pattern,title):
        count +=1
count
# Out:
# 160

# %%
pattern = "WA"
string = "WAqas"
print(re.search(pattern,string))

# %%
pattern = ("e-?mail")
titles.str.contains(pattern)[0].value_counts(dropna=False)#email , e-mail , ? represent mean zero or one
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-c6e73f7ff061> in <module>()
#       1 pattern = ("e-?mail")
# ----> 2 titles.str.contains(pattern)[0].value_counts(dropna=False)#email , e-mail , ? represent mean zero or one
#
# AttributeError: 'numpy.bool_' object has no attribute 'value_counts'

# %% [markdown]
# a? -> a(0,1)
# a+ -> a(1,)
# a* -> a(0,)

# %% [markdown]
# 1000 - 2999
# [12][0-9][0-9][0-9]

# %% [markdown]
# \d means 0 to 9    like  [0-9]
#
# \w [0-9A-Za-z_]
# \s [whitespace, tab , newline(\n)]
# . all above including special character except newline(\n)

# %% [markdown]
#  . k sat b yei km krna hajo oper cell me hoa wa ha

# %%
pattern = "[Jj]java[^Ss]"                  # ^ show negative
string = "I am LEAR\"
# Out:
#   File "<ipython-input-14-6a06ad4586f9>", line 2
#     string = "I am LEAR\"
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
pattern  = r"
# Out:
#   File "<ipython-input-15-3141583bac87>", line 1
#     pattern  = r"
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
pattern = r"[sS]
# Out:
#   File "<ipython-input-16-89ddf0232ee3>", line 1
#     pattern = r"[sS]
#                    ^
# SyntaxError: EOL while scanning string literal

# %%
#STANFORD PYTHON          ------------> DEEPLY PYTHON COURSE HERE

# %%
pattern = r"[Pp]ython[\s][0-9][\.][0-9]"

# %%
pattern r"[cC]
# Out:
#   File "<ipython-input-19-a4e84ee370ef>", line 1
#     pattern r"[cC]
#                  ^
# SyntaxError: EOL while scanning string literal

# %%
url = hacker["url"]
url.head()
# Out:
# 0              http://www.interactivedynamicvideo.com/
# 1    http://hueniverse.com/2016/01/26/how-to-use-op...
# 2    http://www.thewire.com/entertainment/2013/04/f...
# 3    https://www.amazon.com/Technology-Ventures-Ent...
# 4    http://www.nytimes.com/2007/11/07/movies/07ste...
# Name: url, dtype: object

# %%
pattern = r"htps?://([\w\.]+)"
url.str.extract(pattern,flags=re.I)[0].value_counts()
# Out:
# Series([], Name: 0, dtype: int64)

# %%
extract()
