# %%
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get("https://mangapark.net/genre/kids")
response.status_code
# Out:
# 200

# %%
content = response.content
# content

# %%
parser = BeautifulSoup(content,"html.parser")

# %%
parser.select("head")
# Out:
# [<head>\n<meta charset="unicode-escape"/>\n<meta content="width=device-width, initial-scale=1, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, shrink-to-fit=no" name="viewport"/>\n<title>Kids Manga - Directory - MangaPark</title>\n<meta content="Kids Manga - Directory - MangaPark" name="description">\n<meta content="manga,read manga,manga online,magna scans,manga volume,manga chapter,online manga,read free manga,read free manga online,manga genre." name="keywords">\n<meta content="Read Manga Online" property="og:title"/>\n<meta content="MangaPark" property="og:site_name"/>\n<meta content="//static.mangapark.net/img/favicon.gif" property="og:image"/>\n<link href="/rss/latest/kids.xml" rel="alternate" title="RSS" type="application/rss+xml"/>\n<link async="async" crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.6.1/css/all.css" integrity="sha384-gfdkjb5BdAXd+lj+gudLWI+BXq4IuLW5IT+brZEZsLFm++aCMlF1V92rMkPaX4PP" rel="stylesheet"/>\n<link async="async" crossori
# ...

# %%
for i, value in enumerate(parser.find_all("a")):
    print(i,value)
# Out:
# (0, <a href="/" title="Home">\n<img alt="Manga Park" src="//static.mangapark.net/img/logo-2019.png"/>\n</a>)
# (1, <a accesskey="H" href="/">Home</a>)
# (2, <a accesskey="L" href="/latest">Latest</a>)
# (3, <a accesskey="G" href="/genre">Genres</a>)
# (4, <a accesskey="S" href="/search">Search</a>)
# (5, <a class="random" href="/random" title="Surprise!">\n<i class="fas fa-random fa-lg"></i>\n</a>)
# (6, <a href="//my.mangapark.net/setting" title="Setting"><i class="fas fa-cog fa-2x"></i></a>)
# (7, <a class="ml-3" href="//my.mangapark.net/login" title="User"><i class="fas fa-user-circle fa-2x"></i></a>)
# (8, <a href="/search">Advanced search</a>)
# (9, <a class="text-nowrap small" href="/genre" title="All manga">All</a>)
# (10, <a class="text-nowrap small" href="/genre/4-koma" title="4 koma manga">4 koma</a>)
# (11, <a class="text-nowrap small" href="/genre/action" title="Action manga">Action</a>)
# ...

# %%
parser.find_all("span",{"class":"small"})
# Out:
# [<span class="small">46 chapters </span>,
#  <span class="small">10 chapters </span>,
#  <span class="small">38 chapters </span>,
#  <span class="small">12 chapters </span>,
#  <span class="small">5 chapters </span>,
#  <span class="small">7 chapters </span>,
#  <span class="small">1 chapters </span>,
#  <span class="small">13 chapters </span>,
#  <span class="small">1 chapters </span>,
#  <span class="small">5 chapters </span>,
#  <span class="small">5 chapters </span>,
#  <span class="small">4 chapters </span>,
#  <span class="small">5 chapters </span>,
#  <span class="small">3 chapters </span>,
#  <span class="small">3 chapters </span>]
