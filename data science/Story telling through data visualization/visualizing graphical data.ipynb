# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
airports = pd.read_csv("airports.csv")
print(airports.info())
print(airports.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8107 entries, 0 to 8106
# Data columns (total 12 columns):
# id           8107 non-null int64
# name         8107 non-null object
# city         8107 non-null object
# country      8107 non-null object
# code         5880 non-null object
# icao         8043 non-null object
# latitude     8107 non-null float64
# longitude    8107 non-null float64
# altitude     8107 non-null int64
# offset       8107 non-null float64
# dst          8107 non-null object
# timezone     8107 non-null object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 760.1+ KB
# None
#    id                        name          city           country code  icao  \
# 0   1                      Goroka        Goroka  Papua New Guinea  GKA  AYGA
# 1   2                      Madang        Madang  Papua New Guinea  MAG  AYMD
# 2   3                 Mount Hagen   Mount Hagen  Papua New Guinea  HGU  AYMH
# ...

# %%
m = Basemap(projection = "merc" , llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180)
x,y = m(airports["longitude"].tolist(), airports["latitude"].tolist())
m.scatter(x,y, s = 1)

# %%
m = Basemap(projection = "merc" , llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180)
x,y = m(airports["longitude"].tolist(), airports["latitude"].tolist())
m.scatter(x,y, s = 1)
m.drawcoastlines()

# %%
fig, ax = plt.subplots(figsize = (12,12))
m = Basemap(projection = "merc" , llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180)
x,y = m(airports["longitude"].tolist(), airports["latitude"].tolist())
m.scatter(x,y, s = 1)
m.drawcoastlines()

# %%
fig, ax = plt.subplots(figsize = (12,12))
m = Basemap(projection = "merc" , llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180)
x,y = m(airports["longitude"].tolist(), airports["latitude"].tolist())
m.scatter(x,y, s = 10)
m.drawcoastlines()
m.drawrivers()

# %%
fig, ax = plt.subplots(figsize = [12,12])
m = Basemap(projection = "cyl" , llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180)
x,y = m(airports["longitude"].tolist(), airports["latitude"].tolist())
m.scatter(x,y, s = 10)
m.drawcoastlines()
m.drawrivers()

# %%
geo_routes = pd.read_csv("geo_routes.csv")

# %%
def greatcircle(df):
    for i, row in df.iterrows():
        end_lon,start_lon= row["end_lon"], row["start_lon"]
        end_lat, start_lat= row["end_lat"] , row["start_lat"]
        if abs(end_lon - start_lon)< 180:
            if abs(end_lon-start_lon)<180:
                m.drawgreatcircle(start_lon,start_lat,end_lon,end_lat)

# %%
pk = geo_routes[geo_routes["source"] == "PK"]
led = geo_routes[geo_routes["source"] == "LED"]

# %%
fig, ax = plt.subplots(figsize = [12,12])
m = Basemap(projection = "cyl" , llcrnrlat = -80, urcrnrlat = 80, llcrnrlon = -180, urcrnrlon = 180)
x,y = m(airports["longitude"].tolist(), airports["latitude"].tolist())
m.scatter(x,y, s = 10)
m.drawcoastlines()
m.drawrivers()
m.drawmapboundary()
greatcircle(dfw)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-082b40883bce> in <module>()
#       6 m.drawrivers()
#       7 m.drawmapboundary()
# ----> 8 greatcircle(dfw)
#
# NameError: name 'dfw' is not defined

# %%
fig, ax = plt.subplots(figsize = [8,20])
m = Basemap(projection = "ortho" ,lat_0 = 30 , lon_0 = 67)
x,y = m(airports["longitude"].tolist(), airports["latitude"].tolist())
m.scatter(x,y, s = 2)
m.drawcoastlines()
m.drawrivers()
#m.drawmapboundary(fill_color = "aqua")
m.bluemarble()
m.drawcountries(linewidth = 3)
#m.fillcontinents(color = "coral", lake_color = "blue")
plt.text(120,30, "pakistan", bbox= dict(facecolor = "yellow" , alpha=0.5))
m.scatter(68,30,latlon = True, c = "red", s= 500)
greatcircle(pk)
#greatcircle(led)
plt.title("PAKISTAN", fontsize = 50 )
