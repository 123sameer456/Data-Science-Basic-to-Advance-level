# %%
import numpy as np
import pandas as pd

# %%
income=pd.read_csv("income.csv")

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education_num     32561 non-null int64
# marital_status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    32561 non-null object
# high_income       32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
income
# Out:
#        age          workclass  fnlwgt      education  education_num  \
# 0       39          State-gov   77516      Bachelors             13
# 1       50   Self-emp-not-inc   83311      Bachelors             13
# 2       38            Private  215646        HS-grad              9
# 3       53            Private  234721           11th              7
# 4       28            Private  338409      Bachelors             13
# 5       37            Private  284582        Masters             14
# 6       49            Private  160187            9th              5
# 7       52   Self-emp-not-inc  209642        HS-grad              9
# 8       31            Private   45781        Masters             14
# 9       42            Private  159449      Bachelors             13
# 10      37            Private  280464   Some-college             10
# 11      30          State-gov  141297      Bachelors             13
# 12      23            Private  122272      Bachelors             13
# ...

# %%
income["sex"].value_counts()
# Out:
#  Male      21790
#  Female    10771
# Name: sex, dtype: int64

# %%
observed=[21790,10771]
expected=[16280.5,16280.5]
male=(21790-16280.5)/16280.5
female=(10770-16280.5)/16280.5

# %%
print(male)
print(female)
# Out:
# 0.33841098246368356
# -0.33847240563864744

# %%
observed=[21790,10771]
expected=[16280.5,16280.5]
male=((21790-16280.5)**2)/16280.5
female=((10771-16280.5)**2)/16280.5

# %%
print(male)
print(female)
# Out:
# 1864.4753078836645
# 1864.4753078836645

# %%
male+female # chi-squared apply on nominal data
# Out:
# 3728.950615767329

# %%
chisquared=[]
for i in range(1000):
    male=[]
    female=[]
    sequence=np.random.rand(32561)
    sequence[sequence<0.5]=0
    sequence[sequence>0.5]=1
    male=len(sequence[sequence==1])
    female=len(sequence[sequence==0])
    male_change=((male-16280.5)**2)/16280.5
    female_change=((female-16280.5)**2)/16280.5
    gender_chisq=male_change+female_change
    chisquared.append(gender_chisq)

# %%
len(chisquared)
# Out:
# 1000

# %%
# counter=0
# for i in chisquared:
#     if i>=3728.950615767329:
#         counter+=1

# %%
counter
# Out:
# 0

# %%
counter=0
for i in chisquared:
    if i>=3728.950615767329:
        counter.append(i)

# %%
counter
# Out:
# 0

# %%
from scipy.stats import chisquare
chisq,p_value=chisquare(observed,expected)

# %%
chisq
# Out:
# 3728.950615767329

# %%
p_value
# Out:
# 0.0

# %%
income.race.unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %%
income.race.value_counts()
# Out:
#  White                 27816
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: race, dtype: int64

# %%
len(income.race)
# Out:
# 32561

# %%
#Assignment
White=80.3%
Black=12.1%
Asian_Pac_Islander=2.9%
indian=0.8%
Others=3.9%
# Out:
#   File "<ipython-input-33-53934d4c3471>", line 2
#     White=80.3%
#                ^
# SyntaxError: invalid syntax

# %%
80.3+12.1+2.9+0.8+3.9
# Out:
# 100.0

# %%
observed=[]
expected=[]

# %%
cross_tab=pd.crosstab(income["sex"],income["high_income"])

# %%
cross_tab
# Out:
# high_income   <=50K   >50K
# sex
#  Female        9592   1179
#  Male         15128   6662

# %%
observed=[9592,1179,15128,6662]
expected=[]

# %%
female=10771
male=21790

# %%
less50k_f=9592/32561
above50k_f=1179/32561
less50k_m=15128/32561
above50k_m=6662/32561

# %%
df=pd.DataFrame({"<=50k":[less50k_f,less50k_m,less50k_f+less50k_m],">50k":[above50k_f,above50k_m,above50k_f+above50k_m]},index=["Female","Male","total"])
df
# Out:
#            <=50k      >50k
# Female  0.294586  0.036209
# Male    0.464605  0.204601
# total   0.759190  0.240810

# %%
f=less50k_f+above50k_f
m=less50k_m+above50k_m

# %%
df["Total"]=[f,m,f+m]

# %%
df
# Out:
#            <=50k      >50k     Total
# Female  0.294586  0.036209  0.330795
# Male    0.464605  0.204601  0.669205
# total   0.759190  0.240810  1.000000

# %%
f_less50k=32561*0.759190*0.330795
m_less50k=32561*0.759190*0.669205
f_above50k=32561*0.240810*0.330795
m_above50k=32561*0.240810*0.669250

# %%
32561*0.759190*0.330795
# Out:
# 8177.24763324405

# %%
32561*0.294586
# Out:
# 9592.014746

# %%
observed=[9592,1179,15128,6662]
expected=[f_less50k,f_above50k,m_less50k,m_above50k]

# %% [markdown]
# ????

# %%
table=pd.crosstab(income["sex"],income["race"])

# %%
table
# Out:
# race      Amer-Indian-Eskimo   Asian-Pac-Islander   Black   Other   White
# sex
#  Female                  119                  346    1555     109    8642
#  Male                    192                  693    1569     162   19174

# %%
from scipy.stats import chi2_contingency
chisq,p_value,df,expected=chi2_contingency(table)

# %%
chisq,p_value
# Out:
# (454.2671089131088, 5.192061302760456e-97)

# %%
df
# Out:
# 4
