# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
admission = pd.read_csv("admissions.csv")

# %%
admission.head()
# Out:
#    admit       gpa         gre
# 0      0  3.177277  594.102992
# 1      0  3.412655  631.528607
# 2      0  2.728097  553.714399
# 3      0  3.093559  551.089985
# 4      0  3.141923  537.184894

# %%
plt.plot(admission["gpa"],admission["gre"])

# %%
plt.plot(admission["admit"],admission["gre"])

# %%
admission["admit"].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# y = $e^x$/(1 + $e^x$)

# %%
def logistic(x):
    numinator = np.exp(x)
    demominator = 1 + np.exp(x)
    y = numinator/demominator
    return y

# %%
x = np.linspace(-6,6,100)
y = logistic(x)

# %%
plt.plot(x,y)
plt.ylabel("probablity")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(admission[["gpa"]],admission["admit"])
prob = model.predict_proba(admission[["gpa"]])
# Out:
# D:\ProgramData\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
predict = model.predict(admission[["gpa"]])
predict[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %%
admit = prob[:,1]

# %%
plt.scatter(admit,admission["gpa"])

# %%
admission["prediction"] = predict

# %%
admission.head(5)
# Out:
#    admit       gpa         gre  prediction
# 0      0  3.177277  594.102992           0
# 1      0  3.412655  631.528607           0
# 2      0  2.728097  553.714399           0
# 3      0  3.093559  551.089985           0
# 4      0  3.141923  537.184894           0

# %%
correct_label = admission["admit"] == admission["prediction"]

# %%
tot_corr = correct_label.sum()
tot_corr
# Out:
# 416

# %%
accuracy = tot_corr/admission.shape[0]
accuracy
# Out:
# 0

# %% [markdown]
#   ### TPR - SENSITIVITY
#
#   ### TNR - SPECIFICITY

# %% [markdown]
# TPR = TRUE POSITIVELY RESULT
#
# TNR = TRUE NEGATIVE RESULT

# %% [markdown]
# TPR = TP/(TP+FN)
#
# TNR = TN/(TN/FP)

# %%
tp = len(admission[(admission["admit"] ==1) & (admission["prediction"]== 1)])
tn = len(admission[(admission["admit"] ==0) & (admission["prediction"]== 0)])

# %%
fn = len(admission[(admission["admit"] ==1) & (admission["prediction"]== 0)])
fp = len(admission[(admission["admit"] ==0) & (admission["prediction"]== 1)])

# %%
tpr = tp/(tp+fn)
tnr = tn/(tn+fp)

# %%
print(tpr*100)
print(tnr*100)
# Out:
# 0
# 0
