# %%
import pandas as pd

# %%
import sqlite3 as sql

# %%
DB = "jobs.db"

# %%
conn = sql.connect(DB)

# %%
q = """Select * from sqlite_master where type = 'table'"""
pd.read_sql_query(q,conn)
# Out:
#     type          name      tbl_name  rootpage  \
# 0  table  recent_grads  recent_grads         2
#
#                                                  sql
# 0  CREATE TABLE "recent_grads" (\n"index" INTEGER...

# %%
def run_query(q):
    return pd.read_sql_query(q,conn)

# %%
q = """Select * from recent_grads limit 5"""
run_query(q)
# Out:
#    index  Rank  Major_code                                      Major  \
# 0      0     1        2419                      PETROLEUM ENGINEERING
# 1      1     2        2416             MINING AND MINERAL ENGINEERING
# 2      2     3        2415                  METALLURGICAL ENGINEERING
# 3      3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      4     5        2405                       CHEMICAL ENGINEERING
#
#   Major_category  Total  Sample_size    Men  Women  ShareWomen  ...  \
# 0    Engineering   2339           36   2057    282    0.120564  ...
# 1    Engineering    756            7    679     77    0.101852  ...
# 2    Engineering    856            3    725    131    0.153037  ...
# 3    Engineering   1258           16   1123    135    0.107313  ...
# 4    Engineering  32260          289  21239  11021    0.341631  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
q = """Select * from recent_grads where ShareWomen < 0.5 limit 5;"""
run_query(q)
# Out:
#    index  Rank  Major_code                                      Major  \
# 0      0     1        2419                      PETROLEUM ENGINEERING
# 1      1     2        2416             MINING AND MINERAL ENGINEERING
# 2      2     3        2415                  METALLURGICAL ENGINEERING
# 3      3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4      4     5        2405                       CHEMICAL ENGINEERING
#
#   Major_category  Total  Sample_size    Men  Women  ShareWomen  ...  \
# 0    Engineering   2339           36   2057    282    0.120564  ...
# 1    Engineering    756            7    679     77    0.101852  ...
# 2    Engineering    856            3    725    131    0.153037  ...
# 3    Engineering   1258           16   1123    135    0.107313  ...
# 4    Engineering  32260          289  21239  11021    0.341631  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
q = """Select * from recent_grads limit 5"""
run_query(q).columns
# Out:
# Index(['index', 'Rank', 'Major_code', 'Major', 'Major_category', 'Total',
#        'Sample_size', 'Men', 'Women', 'ShareWomen', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
q = """Select Rank,Major_code,Major_category from recent_grads where ShareWomen < 0.5 and Median > 10000 limit 5;"""
run_query(q)
# Out:
#    Rank  Major_code Major_category
# 0     1        2419    Engineering
# 1     2        2416    Engineering
# 2     3        2415    Engineering
# 3     4        2417    Engineering
# 4     5        2405    Engineering

# %%
q = """Select Rank,Men,Women from recent_grads where   Median > 10000 limit 5;"""
run_query(q)
# Out:
#    Rank    Men  Women
# 0     1   2057    282
# 1     2    679     77
# 2     3    725    131
# 3     4   1123    135
# 4     5  21239  11021

# %%
q = """Select Rank,Major_code,Major_category,Major,Median from recent_grads where Major_category = "Engineering" or Median > 100000 limit 5;"""
run_query(q)
# Out:
#    Rank  Major_code Major_category                                      Major  \
# 0     1        2419    Engineering                      PETROLEUM ENGINEERING
# 1     2        2416    Engineering             MINING AND MINERAL ENGINEERING
# 2     3        2415    Engineering                  METALLURGICAL ENGINEERING
# 3     4        2417    Engineering  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4     5        2405    Engineering                       CHEMICAL ENGINEERING
#
#    Median
# 0  110000
# 1   75000
# 2   73000
# 3   70000
# 4   65000

# %%
q = """Select Rank,Major_code,Major_category,Major,Median from recent_grads where Major_category = "Engineering" and (ShareWomen > 0.5 or Unemployment_rate < .05) limit 5;"""
run_query(q)
# Out:
#    Rank  Major_code Major_category                                      Major  \
# 0     1        2419    Engineering                      PETROLEUM ENGINEERING
# 1     3        2415    Engineering                  METALLURGICAL ENGINEERING
# 2    14        5008    Engineering                          MATERIALS SCIENCE
# 3    15        2409    Engineering  ENGINEERING MECHANICS PHYSICS AND SCIENCE
# 4    17        2412    Engineering   INDUSTRIAL AND MANUFACTURING ENGINEERING
#
#    Median
# 0  110000
# 1   73000
# 2   60000
# 3   58000
# 4   57000

# %%
q = """Select Rank,Major_code,Major_category,Major,Median from recent_grads 
where Major_category = "Engineering" and (ShareWomen > 0.5 or Unemployment_rate < .05)
order By Median ASC
limit 5;"""
run_query(q)
# Out:
#    Rank  Major_code Major_category  \
# 0    51        2501    Engineering
# 1    39        2503    Engineering
# 2    31        2410    Engineering
# 3    24        2413    Engineering
# 4    17        2412    Engineering
#
#                                          Major  Median
# 0        ENGINEERING AND INDUSTRIAL MANAGEMENT   44000
# 1           INDUSTRIAL PRODUCTION TECHNOLOGIES   46000
# 2                    ENVIRONMENTAL ENGINEERING   50000
# 3  MATERIALS ENGINEERING AND MATERIALS SCIENCE   52000
# 4     INDUSTRIAL AND MANUFACTURING ENGINEERING   57000
