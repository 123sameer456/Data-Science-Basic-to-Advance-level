# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
unrate = pd.read_csv("unrate.csv")
print(unrate.info())
print(unrate.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
# DATE     824 non-null object
# VALUE    824 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 12.9+ KB
# None
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
#ax2 = fig.add_subplot(2,1,2)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
plt.show()

# %%
fig = plt.figure(figsize = (15,12))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
ax1.plot(unrate["DATE"].head(12),unrate["VALUE"].head(12))
ax2.plot(unrate["DATE"][12:24],unrate["VALUE"][12:24])

plt.show()

# %%
fig = plt.figure(figsize = (15,12))
for i in range(5):
    ax = fig.add_subplot(5,1,i+1)
    start_index = i*12
    ens_index = 12*(1+i)
    ax.plot(unrate["DATE"][start_index:end_index],unrate["VALUE"][start_index:end_index])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9927e0d1a132> in <module>()
#       4     start_index = i*12
#       5     ens_index = 12*(1+i)
# ----> 6     ax.plot(unrate["DATE"][start_index:end_index],unrate["VALUE"][start_index:end_index])
#       7
#       8 plt.show()
#
# NameError: name 'end_index' is not defined

# %%
unrate["month"] = unrate["DATE"].dt

# %%
plt.plot(unrate["month"].head(12),unrate["VALUE"].head(12), label = "1948")
plt.plot(unrate["month"][12:24],unrate["VALUE"][12:24], label = "1948", c ="red")
plt.legend(loc = "upper left")
plt.show()

# %%
colors = ["green","yellow","red", "block","blue"]
for i in range(5):
    ax = fig.add_subplot(5,1,i+1)
    start_index = 12*i
    ens_index = 12*(1+i)
    labels = 1948+i
    ax.plot(unrate["DATE"][start_index:end_index],unrate["VALUE"][start_index:end_index], label=labels = color)
    plt.legend(loc = "upper left")
plt.xlabel("months")
plt.ylabel("unemplyment rate")
plt.title("our class is finished now")

plt.show()
