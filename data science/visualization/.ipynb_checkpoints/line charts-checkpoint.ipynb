# %%
import numpy as np
import pandas as pd
unrate = pd.read_csv("unrate.csv")
print(unrate.info())
print(unrate.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
# DATE     824 non-null object
# VALUE    824 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 12.9+ KB
# None
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5

# %%
import datetime as dt
unrate["DATE"] = pd.to_datetime(unrate["DATE"])
print(unrate["DATE"].dtype)
# Out:
# datetime64[ns]

# %%
unrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
# DATE     824 non-null datetime64[ns]
# VALUE    824 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 12.9 KB

# %%
unrate.head(12)
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0

# %%
#line chart using matplotlib
#agr data order me ha tau line chart use krna ha

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(unrate["DATE"].head(12),unrate["VALUE"].head(12))
plt.show()
# Out:
# D:\ProgramData\Anaconda2\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
plt.plot(unrate["DATE"].head(12),unrate["VALUE"].head(12))
plt.xticks(rotation = 90)
plt.show()

# %%
plt.plot(unrate["DATE"].head(12),unrate["VALUE"].head(12))
plt.xticks(rotation = 90)
plt.hlines(4,"1948-01","1948-12", color = "red")
plt.show()

# %%
plt.plot(unrate["DATE"].head(12),unrate["VALUE"].head(12))
plt.xticks(rotation = 90)
plt.hlines(3.5,"1948-01","1948-12", color = "red")
plt.show()

# %%
plt.plot(unrate["DATE"].head(12),unrate["VALUE"].head(12))
plt.xticks(rotation = 90)
plt.hlines(4,"1948-01","1948-12", color = "red")
plt.xlabel("months,1948")
plt.ylabel("unemployment, rate")
plt.title("monthly  unemployment rate 1948 US ")
plt.show()

# %%
#line chart using pandas

# %%
unrate.head(12).plot("DATE","VALUE", rot = 90, title = "monthly  unemployment rate 1948 US", label = "xyz")
plt.hlines(4,"1948-01","1948-12", color = "red")
plt.xlabel("months,1948")
plt.ylabel("unemployment, rate")
# Out:
# Text(0,0.5,'unemployment, rate')
