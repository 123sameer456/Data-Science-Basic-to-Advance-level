# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
unrate = pd.read_csv("unrate.csv")
print(unrate.info())
print(unrate.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
# DATE     824 non-null object
# VALUE    824 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 12.9+ KB
# None
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
plt.show()

# %%
fig = plt.figure(figsize = (10,9))
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
ax1.plot(unrate["DATE"].head(12),unrate["VALUE"].head(12))
ax2.plot(unrate["DATE"][12:24],unrate["VALUE"][12:24])

plt.show()

# %%
fig = plt.figure(figsize = (15,12))
for i in range(5):
    ax = fig.add_subplot(5,1,i+1)
    start_index = i*12
    end_index = 12*(1+i)
    ax.plot(unrate["DATE"][start_index:end_index],unrate["VALUE"][start_index:end_index])

plt.show()

# %%
#unrate["month"] = pd.to_datetime(unrate["DATE"])

# %%
#unrate["month"]

# %%
plt.plot(unrate["month"].head(12),unrate["VALUE"].head(12), label = "1948")
plt.plot(unrate["month"][12:24],unrate["VALUE"][12:24], label = "1949", c ="red")
plt.plot(unrate["month"][24:36],unrate["VALUE"][24:36], label = "1950", c ="green")
plt.legend(loc = "upper left")
plt.show()

# %%
fig = plt.figure(figsize = (5,1))
colors = ["green","yellow","red", "block","blue"]
for i in range(5):
    ax = fig.add_subplot(5,1,i+1)
    start_index = 12*i
    ens_index = 12*(1+i)
    labels = 1948+i
    ax.plot(unrate["DATE"][start_index : end_index],unrate["VALUE"][start_index : end_index], label= labels , color = colors)
    plt.legend(loc = "upper left")
    plt.xlabel("months")
    plt.ylabel("unemplyment rate")
    plt.title("our class is finished now")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\ProgramData\Anaconda2\lib\site-packages\IPython\core\formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# D:\ProgramData\Anaconda2\lib\site-packages\IPython\core\pylabtools.pyc in <lambda>(fig)
#     245
#     246     if 'png' in formats:
# --> 247         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     248     if 'retina' in formats or 'png2x' in formats:
#     249         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# D:\ProgramData\Anaconda2\lib\site-packages\IPython\core\pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
# ...

# %%
from mpl_toolkits.basemap import Basemap as bmap
